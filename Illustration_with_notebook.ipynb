# %% [markdown]
# # Building a Company Financials Dataset in Python (S&P 500)
#
# In this notebook I walk you step by step through how I build a
# structured dataset of S&P 500 company financials using Python:
#
# 1. Fetch the S&P 500 constituents table from Wikipedia using **requests**
#    and **BeautifulSoup** (to avoid 403 errors).
# 2. Use **yfinance** to talk to Yahoo Finance.
# 3. Pull basic information about each company (name, country, industry, etc.).
# 4. Pull the last 3 years of annual financial statements.
# 5. Combine everything into one tidy table (a pandas DataFrame).
# 6. Save the dataset as CSV and Excel.

# %% [markdown]
# ## Step 0 – Install and import the needed packages
#
# - **pandas** – for working with tables (DataFrames).
# - **yfinance** – for downloading data from Yahoo Finance.
# - **requests** – for making HTTP requests.
# - **BeautifulSoup** – for parsing the HTML from Wikipedia.

# %%
# !pip install pandas yfinance requests beautifulsoup4

# %%
#!pip install lxml

# %%
import time
import pandas as pd
import yfinance as yf
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Step 1 – Get the S&P 500 list with requests + BeautifulSoup
#
# In this step, the S&P 500 constituent list is fetched from Wikipedia.
# On some networks, calling `pandas.read_html` directly on the URL
# can give a **403 Forbidden** error, so I take a slightly more
# manual approach:
#
# 1. The HTML of the page is downloaded using `requests`.
# 2. A browser-like **User-Agent** header is sent to header is sent to make the request appear                                                               more like it is from a normal browser and less like a bot.
# 3. The HTML is parsed using **BeautifulSoup** to find the table with the S&P 500 constituents.
# 4. The table HTML is passed to `pandas.read_html` to turn it into a
#    DataFrame.
#
# A couple of column names are standardised so they can be used later without concern about the exact
# naming on the page (for example, `Symbol` is renamed to `Ticker`).

# %%
def load_sp500_companies(max_companies=500):
    """ Function for loading the S&P 500 constituent table from Wikipedia.

      Parameters:
    ----------
    max_companies : int
        Maximum number of companies to keep. This gives me direct
        control over the "at least 100 and no more than 500" requirement.
    """
    url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

    # 1) Download the HTML
    headers = {
        "User-Agent": (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 (KHTML, like Gecko) "
            "Chrome/124.0 Safari/537.36"
        )
    }

    response = requests.get(url, headers=headers)
    response.raise_for_status()  # raises an error for 4xx/5xx status codes

    html = response.text

    # 2) Parse with BeautifulSoup
    soup = BeautifulSoup(html, "html.parser")

    # 3) Find the main S&P 500 table (id="constituents")
    table = soup.find("table", id="constituents")
    if table is None:
        # Fallback: first table on the page
        table = soup.find("table")
        if table is None:
            raise RuntimeError("Could not find any HTML table on the page")

    # 4) Convert the HTML table to a DataFrame
    df_list = pd.read_html(str(table))
    if not df_list:
        raise RuntimeError("pandas could not read the table HTML")

    sp500 = df_list[0]

    # Standardise column names for later use
    rename_map = {
        "Symbol": "Ticker",
        "Security": "Company",
    }
    sp500 = sp500.rename(columns=rename_map)

    # Limit the universe size
    sp500 = sp500.head(max_companies)
    return sp500


# I call the function once to see what the data looks like
sp500_df = load_sp500_companies(max_companies=150)
sp500_df.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7332\2567963894.py:38: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_list = pd.read_html(str(table))
#   Ticker              Company             GICS Sector  \
# 0    MMM                   3M             Industrials
# 1    AOS          A. O. Smith             Industrials
# 2    ABT  Abbott Laboratories             Health Care
# 3   ABBV               AbbVie             Health Care
# 4    ACN            Accenture  Information Technology
#
#                 GICS Sub-Industry    Headquarters Location  Date added  \
# 0        Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1               Building Products     Milwaukee, Wisconsin  2017-07-26
# 2           Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                   Biotechnology  North Chicago, Illinois  2012-12-31
# 4  IT Consulting & Other Services          Dublin, Ireland  2011-07-06
#
#        CIK      Founded
# 0    66740         1902
# 1    91142         1916
# 2     1800         1888
# 3  1551152  2013 (1888)
# 4  1467373         1989

# %% [markdown]
# In the preview above you should now see a table with columns like
# `Ticker`, `Company`, `GICS Sector`, `GICS Sub-Industry`, and
# `Headquarters Location`.

# %% [markdown]
# ## Step 2 – Get company metadata from Yahoo Finance
#
# Now that the tickers have been obtained, let's know more about each company:
#
# - Full company name
# - Country of the main headquarters
# - Industry and sector
# - Reporting currency
# - Number of employees
# - Market capitalization
#
# The `yfinance.Ticker` object is used, which provides a `.get_info()` method
# that returns a dictionary with many details. This is wrapped in a small helper
# function so it can be reused later.

# %%
def get_company_metadata(ticker_obj):
    """ Function to retrieve basic company metadata from a Yahoo Finance ticker object.

     This function safely queries Yahoo Finance for information about a given company.
    If the data request fails (e.g due to missing fields, connection issues, or API
    inconsistencies), the function returns an empty dictionary instead of raising an error,
    ensuring that failures for individual companies do not interrupt larger batch processes.
    """
    try:
        info = ticker_obj.get_info()
    except Exception:
        return {}

    return {
        "company_name": info.get("longName") or info.get("shortName") or ticker_obj.ticker,
        "country": info.get("country"),
        "industry": info.get("industry"),
        "sector": info.get("sector"),
        "currency": info.get("financialCurrency") or info.get("currency"),
        "employees": info.get("fullTimeEmployees"),
        "market_cap": info.get("marketCap"),
    }


# Quick demo for a single company (Apple)
demo_ticker = yf.Ticker("AAPL")
get_company_metadata(demo_ticker)
# Out:
# {'company_name': 'Apple Inc.',
#  'country': 'United States',
#  'industry': 'Consumer Electronics',
#  'sector': 'Technology',
#  'currency': 'USD',
#  'employees': 166000,
#  'market_cap': 4223723110400}

# %% [markdown]
# The output above is a Python dictionary with key–value pairs such as
# `company_name`, `country`, and so on.

# %% [markdown]
# ## Step 3 – Understand the financial statement data structure
#
# For each company, Yahoo Finance exposes three main annual statements:
#
# - `financials` – income statement (revenue, net income, etc.)
# - `balance_sheet` – balance sheet (assets, liabilities, etc.)
# - `cashflow` – cash flow statement (operating cash flow, etc.)
#
# Each of these is a pandas DataFrame where:
#
# - **Rows** are line items (for example, `Total Revenue`, `Net Income`).
# - **Columns** are year-end dates (for example, `2023-12-31`).
#
# To make life easier, a helper function called `safe_get_item` is written
# that tries to pull one specific line for one date and returns
# `None` if the data is missing.

# %%
def safe_get_item(df, row_label, date):
    """ Safely gets a single numeric value from a financial statement.

    - `df` is the DataFrame (income statement, balance sheet, or cashflow).
    - `row_label` is the line item I am interested in, such as
      'Total Revenue' or 'Net Income'.
    - `date` is the column (a specific period end).
    """
    if df is None or df.empty:
        return None
    if row_label not in df.index:
        return None
    if date not in df.columns:
        return None

    value = df.loc[row_label, date]
    return float(value) if pd.notna(value) else None


# Quick illustration with Apple again
income_demo = demo_ticker.financials
income_demo
# Out:
#                                                       2025-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.560000e-01
# Normalized EBITDA                                   1.447480e+11
# Net Income From Continuing Operation Net Minori...  1.120100e+11
# Reconciled Depreciation                             1.169800e+10
# Reconciled Cost Of Revenue                          2.209600e+11
# EBITDA                                              1.447480e+11
# EBIT                                                1.330500e+11
# Net Interest Income                                          NaN
# Interest Expense                                             NaN
# Interest Income                                              NaN
# Normalized Income                                   1.120100e+11
# Net Income From Continuing And Discontinued Ope...  1.120100e+11
# Total Expenses                                      2.831110e+11
# Total Operating Income As Reported                  1.330500e+11
# Diluted Average Shares                              1.500470e+10
# Basic Average Shares                                1.494850e+10
# Diluted EPS                                         7.460000e+00
# Basic EPS                                           7.490000e+00
# Diluted NI Availto Com Stockholders                 1.120100e+11
# Net Income Common Stockholders                      1.120100e+11
# Net Income                                          1.120100e+11
# Net Income Including Noncontrolling Interests       1.120100e+11
# Net Income Continuous Operations                    1.120100e+11
# Tax Provision                                       2.071900e+10
# Pretax Income                                       1.327290e+11
# Other Income Expense                               -3.210000e+08
# Other Non Operating Income Expenses                -3.210000e+08
# Net Non Operating Interest Income Expense                    NaN
# Interest Expense Non Operating                               NaN
# Interest Income Non Operating                                NaN
# Operating Income                                    1.330500e+11
# Operating Expense                                   6.215100e+10
# Research And Development                            3.455000e+10
# Selling General And Administration                  2.760100e+10
# Gross Profit                                        1.952010e+11
# Cost Of Revenue                                     2.209600e+11
# Total Revenue                                       4.161610e+11
# Operating Revenue                                   4.161610e+11
#
#                                                       2024-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  2.410000e-01
# Normalized EBITDA                                   1.346610e+11
# Net Income From Continuing Operation Net Minori...  9.373600e+10
# Reconciled Depreciation                             1.144500e+10
# Reconciled Cost Of Revenue                          2.103520e+11
# EBITDA                                              1.346610e+11
# EBIT                                                1.232160e+11
# Net Interest Income                                          NaN
# Interest Expense                                             NaN
# Interest Income                                              NaN
# Normalized Income                                   9.373600e+10
# Net Income From Continuing And Discontinued Ope...  9.373600e+10
# Total Expenses                                      2.678190e+11
# Total Operating Income As Reported                  1.232160e+11
# Diluted Average Shares                              1.540810e+10
# Basic Average Shares                                1.534378e+10
# Diluted EPS                                         6.080000e+00
# Basic EPS                                           6.110000e+00
# Diluted NI Availto Com Stockholders                 9.373600e+10
# Net Income Common Stockholders                      9.373600e+10
# Net Income                                          9.373600e+10
# Net Income Including Noncontrolling Interests       9.373600e+10
# Net Income Continuous Operations                    9.373600e+10
# Tax Provision                                       2.974900e+10
# Pretax Income                                       1.234850e+11
# Other Income Expense                                2.690000e+08
# Other Non Operating Income Expenses                 2.690000e+08
# Net Non Operating Interest Income Expense                    NaN
# Interest Expense Non Operating                               NaN
# Interest Income Non Operating                                NaN
# Operating Income                                    1.232160e+11
# Operating Expense                                   5.746700e+10
# Research And Development                            3.137000e+10
# Selling General And Administration                  2.609700e+10
# Gross Profit                                        1.806830e+11
# Cost Of Revenue                                     2.103520e+11
# Total Revenue                                       3.910350e+11
# Operating Revenue                                   3.910350e+11
#
#                                                       2023-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.470000e-01
# Normalized EBITDA                                   1.258200e+11
# Net Income From Continuing Operation Net Minori...  9.699500e+10
# Reconciled Depreciation                             1.151900e+10
# Reconciled Cost Of Revenue                          2.141370e+11
# EBITDA                                              1.258200e+11
# EBIT                                                1.143010e+11
# Net Interest Income                                -1.830000e+08
# Interest Expense                                    3.933000e+09
# Interest Income                                     3.750000e+09
# Normalized Income                                   9.699500e+10
# Net Income From Continuing And Discontinued Ope...  9.699500e+10
# Total Expenses                                      2.689840e+11
# Total Operating Income As Reported                  1.143010e+11
# Diluted Average Shares                              1.581255e+10
# Basic Average Shares                                1.574423e+10
# Diluted EPS                                         6.130000e+00
# Basic EPS                                           6.160000e+00
# Diluted NI Availto Com Stockholders                 9.699500e+10
# Net Income Common Stockholders                      9.699500e+10
# Net Income                                          9.699500e+10
# Net Income Including Noncontrolling Interests       9.699500e+10
# Net Income Continuous Operations                    9.699500e+10
# Tax Provision                                       1.674100e+10
# Pretax Income                                       1.137360e+11
# Other Income Expense                               -5.650000e+08
# Other Non Operating Income Expenses                -5.650000e+08
# Net Non Operating Interest Income Expense          -1.830000e+08
# Interest Expense Non Operating                      3.933000e+09
# Interest Income Non Operating                       3.750000e+09
# Operating Income                                    1.143010e+11
# Operating Expense                                   5.484700e+10
# Research And Development                            2.991500e+10
# Selling General And Administration                  2.493200e+10
# Gross Profit                                        1.691480e+11
# Cost Of Revenue                                     2.141370e+11
# Total Revenue                                       3.832850e+11
# Operating Revenue                                   3.832850e+11
#
#                                                       2022-09-30    2021-09-30
# Tax Effect Of Unusual Items                         0.000000e+00           NaN
# Tax Rate For Calcs                                  1.620000e-01           NaN
# Normalized EBITDA                                   1.305410e+11           NaN
# Net Income From Continuing Operation Net Minori...  9.980300e+10           NaN
# Reconciled Depreciation                             1.110400e+10           NaN
# Reconciled Cost Of Revenue                          2.235460e+11           NaN
# EBITDA                                              1.305410e+11           NaN
# EBIT                                                1.194370e+11           NaN
# Net Interest Income                                -1.060000e+08  1.980000e+08
# Interest Expense                                    2.931000e+09  2.645000e+09
# Interest Income                                     2.825000e+09  2.843000e+09
# Normalized Income                                   9.980300e+10           NaN
# Net Income From Continuing And Discontinued Ope...  9.980300e+10           NaN
# Total Expenses                                      2.748910e+11           NaN
# Total Operating Income As Reported                  1.194370e+11           NaN
# Diluted Average Shares                              1.632582e+10           NaN
# Basic Average Shares                                1.621596e+10           NaN
# Diluted EPS                                         6.110000e+00           NaN
# Basic EPS                                           6.150000e+00           NaN
# Diluted NI Availto Com Stockholders                 9.980300e+10           NaN
# Net Income Common Stockholders                      9.980300e+10           NaN
# Net Income                                          9.980300e+10           NaN
# Net Income Including Noncontrolling Interests       9.980300e+10           NaN
# Net Income Continuous Operations                    9.980300e+10           NaN
# Tax Provision                                       1.930000e+10           NaN
# Pretax Income                                       1.191030e+11           NaN
# Other Income Expense                               -3.340000e+08           NaN
# Other Non Operating Income Expenses                -3.340000e+08           NaN
# Net Non Operating Interest Income Expense          -1.060000e+08  1.980000e+08
# Interest Expense Non Operating                      2.931000e+09  2.645000e+09
# Interest Income Non Operating                       2.825000e+09  2.843000e+09
# Operating Income                                    1.194370e+11           NaN
# Operating Expense                                   5.134500e+10           NaN
# Research And Development                            2.625100e+10           NaN
# Selling General And Administration                  2.509400e+10           NaN
# Gross Profit                                        1.707820e+11           NaN
# Cost Of Revenue                                     2.235460e+11           NaN
# Total Revenue                                       3.943280e+11           NaN
# Operating Revenue                                   3.943280e+11           NaN

# %% [markdown]
# In the DataFrame above you can see the rows and columns that `safe_get_item`
# will be working with.

# %% [markdown]
# ## Step 4 – Pull the last 3 years of financials for one company
#
# Now everything is put together for a **single ticker symbol**. The function
# `extract_company_financials_for_last_years` will:
#
# 1. Create a `yfinance.Ticker` object.
# 2. Fetch metadata (name, country, industry, etc.).
# 3. Fetch the three financial statements.
# 4. Look at the column dates, sort them from newest to oldest, and keep
#    the most recent 3.
# 5. For each of these dates, create one dictionary (one "row") with:
#    - Ticker
#    - Company name, country, industry, sector
#    - Year
#    - Revenue + revenue currency
#    - Net income, gross profit, total assets, operating cash flow
#    - Employees and market cap (these are current, not per year, but
#      they are still useful KPIs).
#
# The function returns a list of dictionaries, ready to be turned into
# a DataFrame later.

# %%
def extract_company_financials_for_last_years(ticker_symbol, max_years=3):
    """ Collects up to `max_years` of annual financials for one company.

    This returns a list of dictionaries. Each dictionary represents
    one company–year combination.
    """
    ticker_obj = yf.Ticker(ticker_symbol)

    # 1) Basic metadata
    meta = get_company_metadata(ticker_obj)

    # 2) Financial statements
    try:
        income = ticker_obj.financials
        balance_sheet = ticker_obj.balance_sheet
        cashflow = ticker_obj.cashflow
    except Exception:
        return []

    if income is None or income.empty:
        return []

    all_dates = list(income.columns)
    if not all_dates:
        return []

    # Sort dates from newest to oldest and keep the first few
    sorted_dates = sorted(all_dates, reverse=True)
    selected_dates = sorted_dates[:max_years]

    rows = []

    for dt in selected_dates:
        year = pd.to_datetime(dt).year

        row = {
            "ticker": ticker_symbol,
            "company_name": meta.get("company_name"),
            "country": meta.get("country"),
            "industry": meta.get("industry"),
            "sector": meta.get("sector"),
            "year": int(year),
            # Revenue and its currency
            "revenue": safe_get_item(income, "Total Revenue", dt),
            "revenue_currency": meta.get("currency"),
            # Additional KPIs
            "net_income": safe_get_item(income, "Net Income", dt),
            "gross_profit": safe_get_item(income, "Gross Profit", dt),
            "total_assets": safe_get_item(balance_sheet, "Total Assets", dt),
            "operating_cash_flow": safe_get_item(
                cashflow,
                "Total Cash From Operating Activities",
                dt,
            ),
            # Snapshot KPIs
            "employees": meta.get("employees"),
            "market_cap": meta.get("market_cap"),
        }

        rows.append(row)

    return rows


# Test the function for one ticker
extract_company_financials_for_last_years("AAPL", max_years=3)
# Out:
# [{'ticker': 'AAPL',
#   'company_name': 'Apple Inc.',
#   'country': 'United States',
#   'industry': 'Consumer Electronics',
#   'sector': 'Technology',
#   'year': 2025,
#   'revenue': 416161000000.0,
#   'revenue_currency': 'USD',
#   'net_income': 112010000000.0,
#   'gross_profit': 195201000000.0,
#   'total_assets': 359241000000.0,
#   'operating_cash_flow': None,
#   'employees': 166000,
#   'market_cap': 4223659671552},
#  {'ticker': 'AAPL',
#   'company_name': 'Apple Inc.',
#   'country': 'United States',
#   'industry': 'Consumer Electronics',
#   'sector': 'Technology',
#   'year': 2024,
#   'revenue': 391035000000.0,
#   'revenue_currency': 'USD',
#   'net_income': 93736000000.0,
#   'gross_profit': 180683000000.0,
#   'total_assets': 364980000000.0,
#   'operating_cash_flow': None,
#   'employees': 166000,
#   'market_cap': 4223659671552},
#  {'ticker': 'AAPL',
#   'company_name': 'Apple Inc.',
#   'country': 'United States',
#   'industry': 'Consumer Electronics',
#   'sector': 'Technology',
#   'year': 2023,
#   'revenue': 383285000000.0,
#   'revenue_currency': 'USD',
#   'net_income': 96995000000.0,
#   'gross_profit': 169148000000.0,
#   'total_assets': 352583000000.0,
#   'operating_cash_flow': None,
#   'employees': 166000,
#   'market_cap': 4223659671552}]

# %% [markdown]
# The result is a small list of dictionaries, each describing one year of
# financials for Apple.

# %% [markdown]
# ## Step 5 – Loop over many companies and build the full dataset
#
# Now scalling up from one company to many is done by:
#
# 1. Looping over the first `max_companies` rows in the S&P 500 table.
# 2. For each ticker, `extract_company_financials_for_last_years` is called.
# 3. All the small lists are accumulated into one big list.
# 4. That list is converted into a single pandas DataFrame.
# 5. Rows where revenue is missing are optionally dropped to keep the dataset clean.
#
# Additionally, a small `sleep_seconds` pause is added between requests so that the
# Yahoo Finance servers are not hammered too aggressively.

# %%
def build_financial_dataset_from_sp500(
    max_companies=150,
    max_years_per_company=3,
    sleep_seconds=0.5,
):
    """ This function creates the full multi-year dataset for a subset of S&P 500.

    Returns a pandas DataFrame with one row per company–year.
    """
    sp500 = load_sp500_companies(max_companies=max_companies)

    all_rows = []

    for i, row in sp500.iterrows():
        ticker_symbol = row["Ticker"]  # uses the renamed column
        print(f"[{i+1}/{len(sp500)}] Processing {ticker_symbol}...")

        try:
            company_rows = extract_company_financials_for_last_years(
                ticker_symbol=ticker_symbol,
                max_years=max_years_per_company,
            )
            all_rows.extend(company_rows)
        except Exception as e:
            print(f"  -> Skipping {ticker_symbol} due to error: {e}")

        time.sleep(sleep_seconds)

    dataset = pd.DataFrame(all_rows)

    # Optional cleaning step: keep only rows where revenue is present
    if "revenue" in dataset.columns:
        dataset = dataset[dataset["revenue"].notna()]

    return dataset


# This line actually builds the dataset. Depending on your internet
# connection it can take a while. You can lower max_companies for
# quicker experimentation.
financial_dataset = build_financial_dataset_from_sp500(
    max_companies=150,       # adjust between 100 and 500
    max_years_per_company=3,
    sleep_seconds=0.7,
)

financial_dataset.head(), financial_dataset.shape
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7332\2567963894.py:38: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_list = pd.read_html(str(table))
# [1/150] Processing MMM...
# [2/150] Processing AOS...
# [3/150] Processing ABT...
# [4/150] Processing ABBV...
# [5/150] Processing ACN...
# [6/150] Processing ADBE...
# [7/150] Processing AMD...
# [8/150] Processing AES...
# [9/150] Processing AFL...
# [10/150] Processing A...
# [11/150] Processing APD...
# [12/150] Processing ABNB...
# [13/150] Processing AKAM...
# [14/150] Processing ALB...
# [15/150] Processing ARE...
# [16/150] Processing ALGN...
# [17/150] Processing ALLE...
# [18/150] Processing LNT...
# [19/150] Processing ALL...
# [20/150] Processing GOOGL...
# [21/150] Processing GOOG...
# [22/150] Processing MO...
# [23/150] Processing AMZN...
# [24/150] Processing AMCR...
# [25/150] Processing AEE...
# [26/150] Processing AEP...
# [27/150] Processing AXP...
# [28/150] Processing AIG...
# [29/150] Processing AMT...
# [30/150] Processing AWK...
# [31/150] Processing AMP...
# [32/150] Processing AME...
# [33/150] Processing AMGN...
# [34/150] Processing APH...
# [35/150] Processing ADI...
# [36/150] Processing AON...
# [37/150] Processing APA...
# [38/150] Processing APO...
# [39/150] Processing AAPL...
# [40/150] Processing AMAT...
# [41/150] Processing APP...
# [42/150] Processing APTV...
# [43/150] Processing ACGL...
# [44/150] Processing ADM...
# [45/150] Processing ANET...
# [46/150] Processing AJG...
# [47/150] Processing AIZ...
# [48/150] Processing T...
# [49/150] Processing ATO...
# [50/150] Processing ADSK...
# [51/150] Processing ADP...
# [52/150] Processing AZO...
# [53/150] Processing AVB...
# [54/150] Processing AVY...
# [55/150] Processing AXON...
# [56/150] Processing BKR...
# [57/150] Processing BALL...
# [58/150] Processing BAC...
# [59/150] Processing BAX...
# [60/150] Processing BDX...
# [61/150] Processing BRK.B...
# [62/150] Processing BBY...
# [63/150] Processing TECH...
# [64/150] Processing BIIB...
# [65/150] Processing BLK...
# [66/150] Processing BX...
# [67/150] Processing XYZ...
# [68/150] Processing BK...
# [69/150] Processing BA...
# [70/150] Processing BKNG...
# [71/150] Processing BSX...
# [72/150] Processing BMY...
# [73/150] Processing AVGO...
# [74/150] Processing BR...
# [75/150] Processing BRO...
# [76/150] Processing BF.B...
# [77/150] Processing BLDR...
# [78/150] Processing BG...
# [79/150] Processing BXP...
# [80/150] Processing CHRW...
# [81/150] Processing CDNS...
# [82/150] Processing CPT...
# [83/150] Processing CPB...
# [84/150] Processing COF...
# [85/150] Processing CAH...
# [86/150] Processing CCL...
# [87/150] Processing CARR...
# [88/150] Processing CAT...
# [89/150] Processing CBOE...
# [90/150] Processing CBRE...
# [91/150] Processing CDW...
# [92/150] Processing COR...
# [93/150] Processing CNC...
# [94/150] Processing CNP...
# [95/150] Processing CF...
# [96/150] Processing CRL...
# [97/150] Processing SCHW...
# [98/150] Processing CHTR...
# [99/150] Processing CVX...
# [100/150] Processing CMG...
# [101/150] Processing CB...
# [102/150] Processing CHD...
# [103/150] Processing CI...
# [104/150] Processing CINF...
# [105/150] Processing CTAS...
# [106/150] Processing CSCO...
# [107/150] Processing C...
# [108/150] Processing CFG...
# [109/150] Processing CLX...
# [110/150] Processing CME...
# [111/150] Processing CMS...
# [112/150] Processing KO...
# [113/150] Processing CTSH...
# [114/150] Processing COIN...
# [115/150] Processing CL...
# [116/150] Processing CMCSA...
# [117/150] Processing CAG...
# [118/150] Processing COP...
# [119/150] Processing ED...
# [120/150] Processing STZ...
# [121/150] Processing CEG...
# [122/150] Processing COO...
# [123/150] Processing CPRT...
# [124/150] Processing GLW...
# [125/150] Processing CPAY...
# [126/150] Processing CTVA...
# [127/150] Processing CSGP...
# [128/150] Processing COST...
# [129/150] Processing CTRA...
# [130/150] Processing CRWD...
# [131/150] Processing CCI...
# [132/150] Processing CSX...
# [133/150] Processing CMI...
# [134/150] Processing CVS...
# [135/150] Processing DHR...
# [136/150] Processing DRI...
# [137/150] Processing DDOG...
# [138/150] Processing DVA...
# [139/150] Processing DAY...
# [140/150] Processing DECK...
# [141/150] Processing DE...
# [142/150] Processing DELL...
# [143/150] Processing DAL...
# [144/150] Processing DVN...
# [145/150] Processing DXCM...
# [146/150] Processing FANG...
# [147/150] Processing DLR...
# [148/150] Processing DG...
# [149/150] Processing DLTR...
# [150/150] Processing D...
# (  ticker             company_name        country  \
#  0    MMM               3M Company  United States
#  1    MMM               3M Company  United States
#  2    MMM               3M Company  United States
#  3    AOS  A. O. Smith Corporation  United States
#  4    AOS  A. O. Smith Corporation  United States
#
#                           industry       sector  year       revenue  \
#  0                   Conglomerates  Industrials  2024  2.457500e+10
#  1                   Conglomerates  Industrials  2023  2.461000e+10
#  2                   Conglomerates  Industrials  2022  3.422900e+10
#  3  Specialty Industrial Machinery  Industrials  2024  3.818100e+09
#  4  Specialty Industrial Machinery  Industrials  2023  3.852800e+09
#
#    revenue_currency    net_income  gross_profit  total_assets  \
#  0              USD  4.173000e+09  1.012800e+10  3.986800e+10
#  1              USD -6.995000e+09  9.627000e+09  5.058000e+10
#  2              USD  5.777000e+09  1.499700e+10  4.645500e+10
#  3              USD  5.336000e+08  1.456100e+09  3.240000e+09
#  4              USD  5.566000e+08  1.484800e+09  3.213900e+09
#
#    operating_cash_flow  employees   market_cap
#  0                None    61500.0  92160917504
#  1                None    61500.0  92160917504
#  2                None    61500.0  92160917504
#  3                None    12700.0   9394287616
#  4                None    12700.0   9394287616  ,
#  (442, 14))

# %%
financial_dataset
# Out:
#     ticker             company_name        country  \
# 0      MMM               3M Company  United States
# 1      MMM               3M Company  United States
# 2      MMM               3M Company  United States
# 3      AOS  A. O. Smith Corporation  United States
# 4      AOS  A. O. Smith Corporation  United States
# ..     ...                      ...            ...
# 439   DLTR        Dollar Tree, Inc.  United States
# 440   DLTR        Dollar Tree, Inc.  United States
# 441      D    Dominion Energy, Inc.  United States
# 442      D    Dominion Energy, Inc.  United States
# 443      D    Dominion Energy, Inc.  United States
#
#                            industry              sector  year       revenue  \
# 0                     Conglomerates         Industrials  2024  2.457500e+10
# 1                     Conglomerates         Industrials  2023  2.461000e+10
# 2                     Conglomerates         Industrials  2022  3.422900e+10
# 3    Specialty Industrial Machinery         Industrials  2024  3.818100e+09
# 4    Specialty Industrial Machinery         Industrials  2023  3.852800e+09
# ..                              ...                 ...   ...           ...
# 439                 Discount Stores  Consumer Defensive  2024  1.678110e+10
# 440                 Discount Stores  Consumer Defensive  2023  1.541150e+10
# 441  Utilities - Regulated Electric           Utilities  2024  1.445900e+10
# 442  Utilities - Regulated Electric           Utilities  2023  1.439300e+10
# 443  Utilities - Regulated Electric           Utilities  2022  1.393800e+10
#
#     revenue_currency    net_income  gross_profit  total_assets  \
# 0                USD  4.173000e+09  1.012800e+10  3.986800e+10
# 1                USD -6.995000e+09  9.627000e+09  5.058000e+10
# 2                USD  5.777000e+09  1.499700e+10  4.645500e+10
# 3                USD  5.336000e+08  1.456100e+09  3.240000e+09
# 4                USD  5.566000e+08  1.484800e+09  3.213900e+09
# ..               ...           ...           ...           ...
# 439              USD -9.984000e+08  6.019700e+09  2.202350e+10
# 440              USD  1.615400e+09  5.781300e+09  2.302210e+10
# 441              USD  2.124000e+09  6.922000e+09  1.024150e+11
# 442              USD  2.031000e+09  6.958000e+09  1.090800e+11
# 443              USD  1.191000e+09  6.377000e+09  1.047950e+11
#
#     operating_cash_flow  employees   market_cap
# 0                  None    61500.0  92160917504
# 1                  None    61500.0  92160917504
# 2                  None    61500.0  92160917504
# 3                  None    12700.0   9394287616
# 4                  None    12700.0   9394287616
# ..                  ...        ...          ...
# 439                None    64434.0  23782975488
# 440                None    64434.0  23782975488
# 441                None    14700.0  51268956160
# 442                None    14700.0  51268956160
# 443                None    14700.0  51268956160
#
# [442 rows x 14 columns]

# %%
# --- Scale money columns to billions for easier readability and rename them, drop operating_cash_flow ---

# 1) List of monetary columns I want in billions
money_cols = ["revenue", "net_income", "gross_profit", "total_assets", "market_cap"]

# 2) Convert from units (usually dollars) to billions
#    e.g. 10000000000 → 10.0
financial_dataset[money_cols] = financial_dataset[money_cols] / 1e9

# 3) Rename the columns to make it clear they are in billions of dollars
financial_dataset = financial_dataset.rename(columns={
    "revenue": "revenue_in_$B",
    "net_income": "net_income_in_$B",
    "gross_profit": "gross_profit_in_$B",
    "total_assets": "total_assets_in_$B",
    "market_cap": "market_cap_in_$B",
})

# 4) Drop operating_cash_flow entirely
financial_dataset = financial_dataset.drop(columns=["operating_cash_flow"])

financial_dataset["employees"] = (
    pd.to_numeric(financial_dataset["employees"], errors="coerce")
      .round(0)
      .astype("Int64")
)
# Quick check
financial_dataset.head()
# Out:
#   ticker             company_name        country  \
# 0    MMM               3M Company  United States
# 1    MMM               3M Company  United States
# 2    MMM               3M Company  United States
# 3    AOS  A. O. Smith Corporation  United States
# 4    AOS  A. O. Smith Corporation  United States
#
#                          industry       sector  year  revenue_in_$B  \
# 0                   Conglomerates  Industrials  2024        24.5750
# 1                   Conglomerates  Industrials  2023        24.6100
# 2                   Conglomerates  Industrials  2022        34.2290
# 3  Specialty Industrial Machinery  Industrials  2024         3.8181
# 4  Specialty Industrial Machinery  Industrials  2023         3.8528
#
#   revenue_currency  net_income_in_$B  gross_profit_in_$B  total_assets_in_$B  \
# 0              USD            4.1730             10.1280             39.8680
# 1              USD           -6.9950              9.6270             50.5800
# 2              USD            5.7770             14.9970             46.4550
# 3              USD            0.5336              1.4561              3.2400
# 4              USD            0.5566              1.4848              3.2139
#
#    employees  market_cap_in_$B
# 0      61500         92.160918
# 1      61500         92.160918
# 2      61500         92.160918
# 3      12700          9.394288
# 4      12700          9.394288

# %% [markdown]
# The tuple printed above shows:
#
# - A preview of the first few rows.
# - The overall shape `(number_of_rows, number_of_columns)`.
#
# Each row represents a **company–year**, and the columns include:
#
# - `ticker`, `company_name`, `country`, `industry`, `sector`
# - `year`
# - `revenue`, `revenue_currency`
# - `net_income`, `gross_profit`, `total_assets`, `operating_cash_flow`
# - `employees`, `market_cap`

# %% [markdown]
# # Validation :  Looking for missing values.

# %%
financial_dataset.isna().sum()
# Out:
# ticker                 0
# company_name           0
# country                0
# industry               0
# sector                 0
# year                   0
# revenue_in_$B          0
# revenue_currency       0
# net_income_in_$B       0
# gross_profit_in_$B    54
# total_assets_in_$B     0
# employees              2
# market_cap_in_$B       0
# dtype: int64

# %%
# Missing gross profit rows:
financial_dataset[financial_dataset["gross_profit_in_$B"].isna()]
# Out:
#     ticker                             company_name        country  \
# 24     AFL                       Aflac Incorporated  United States
# 25     AFL                       Aflac Incorporated  United States
# 26     AFL                       Aflac Incorporated  United States
# 54     ALL                 The Allstate Corporation  United States
# 55     ALL                 The Allstate Corporation  United States
# 56     ALL                 The Allstate Corporation  United States
# 78     AXP                 American Express Company  United States
# 79     AXP                 American Express Company  United States
# 80     AXP                 American Express Company  United States
# 81     AIG       American International Group, Inc.  United States
# 82     AIG       American International Group, Inc.  United States
# 83     AIG       American International Group, Inc.  United States
# 90     AMP               Ameriprise Financial, Inc.  United States
# 91     AMP               Ameriprise Financial, Inc.  United States
# 92     AMP               Ameriprise Financial, Inc.  United States
# 126   ACGL                  Arch Capital Group Ltd.        Bermuda
# 127   ACGL                  Arch Capital Group Ltd.        Bermuda
# 128   ACGL                  Arch Capital Group Ltd.        Bermuda
# 138    AIZ                           Assurant, Inc.  United States
# 139    AIZ                           Assurant, Inc.  United States
# 140    AIZ                           Assurant, Inc.  United States
# 171    BAC              Bank of America Corporation  United States
# 172    BAC              Bank of America Corporation  United States
# 173    BAC              Bank of America Corporation  United States
# 192     BX                          Blackstone Inc.  United States
# 193     BX                          Blackstone Inc.  United States
# 194     BX                          Blackstone Inc.  United States
# 198     BK  The Bank of New York Mellon Corporation  United States
# 199     BK  The Bank of New York Mellon Corporation  United States
# 200     BK  The Bank of New York Mellon Corporation  United States
# 204   BKNG                    Booking Holdings Inc.  United States
# 205   BKNG                    Booking Holdings Inc.  United States
# 206   BKNG                    Booking Holdings Inc.  United States
# 243    COF        Capital One Financial Corporation  United States
# 244    COF        Capital One Financial Corporation  United States
# 245    COF        Capital One Financial Corporation  United States
# 282   SCHW           The Charles Schwab Corporation  United States
# 283   SCHW           The Charles Schwab Corporation  United States
# 284   SCHW           The Charles Schwab Corporation  United States
# 294     CB                            Chubb Limited    Switzerland
# 295     CB                            Chubb Limited    Switzerland
# 296     CB                            Chubb Limited    Switzerland
# 300     CI                          The Cigna Group  United States
# 301     CI                          The Cigna Group  United States
# 302     CI                          The Cigna Group  United States
# 303   CINF         Cincinnati Financial Corporation  United States
# 304   CINF         Cincinnati Financial Corporation  United States
# 305   CINF         Cincinnati Financial Corporation  United States
# 312      C                           Citigroup Inc.  United States
# 313      C                           Citigroup Inc.  United States
# 314      C                           Citigroup Inc.  United States
# 315    CFG           Citizens Financial Group, Inc.  United States
# 316    CFG           Citizens Financial Group, Inc.  United States
# 317    CFG           Citizens Financial Group, Inc.  United States
#
#                             industry              sector  year  revenue_in_$B  \
# 24                  Insurance - Life  Financial Services  2024      19.128000
# 25                  Insurance - Life  Financial Services  2023      18.841000
# 26                  Insurance - Life  Financial Services  2022      19.151000
# 54   Insurance - Property & Casualty  Financial Services  2024      63.515000
# 55   Insurance - Property & Casualty  Financial Services  2023      56.591000
# 56   Insurance - Property & Casualty  Financial Services  2022      50.617000
# 78                   Credit Services  Financial Services  2024      65.949000
# 79                   Credit Services  Financial Services  2023      60.515000
# 80                   Credit Services  Financial Services  2022      52.862000
# 81           Insurance - Diversified  Financial Services  2024      27.270000
# 82           Insurance - Diversified  Financial Services  2023      27.959000
# 83           Insurance - Diversified  Financial Services  2022      29.975000
# 90                  Asset Management  Financial Services  2024      17.264000
# 91                  Asset Management  Financial Services  2023      15.535000
# 92                  Asset Management  Financial Services  2022      14.258000
# 126          Insurance - Diversified  Financial Services  2024      16.930000
# 127          Insurance - Diversified  Financial Services  2023      13.297000
# 128          Insurance - Diversified  Financial Services  2022       9.613000
# 138  Insurance - Property & Casualty  Financial Services  2024      11.877500
# 139  Insurance - Property & Casualty  Financial Services  2023      11.131600
# 140  Insurance - Property & Casualty  Financial Services  2022      10.193000
# 171              Banks - Diversified  Financial Services  2024     101.887000
# 172              Banks - Diversified  Financial Services  2023      98.581000
# 173              Banks - Diversified  Financial Services  2022      94.950000
# 192                 Asset Management  Financial Services  2024      10.930540
# 193                 Asset Management  Financial Services  2023       7.006649
# 194                 Asset Management  Financial Services  2022       7.132632
# 198              Banks - Diversified  Financial Services  2024      18.258000
# 199              Banks - Diversified  Financial Services  2023      17.488000
# 200              Banks - Diversified  Financial Services  2022      16.186000
# 204                  Travel Services   Consumer Cyclical  2024      23.739000
# 205                  Travel Services   Consumer Cyclical  2023      21.365000
# 206                  Travel Services   Consumer Cyclical  2022      17.090000
# 243                  Credit Services  Financial Services  2024      39.112000
# 244                  Credit Services  Financial Services  2023      36.787000
# 245                  Credit Services  Financial Services  2022      34.250000
# 282                  Capital Markets  Financial Services  2024      19.606000
# 283                  Capital Markets  Financial Services  2023      18.837000
# 284                  Capital Markets  Financial Services  2022      20.762000
# 294  Insurance - Property & Casualty  Financial Services  2024      56.150000
# 295  Insurance - Property & Casualty  Financial Services  2023      50.133000
# 296  Insurance - Property & Casualty  Financial Services  2022      42.975000
# 300                 Healthcare Plans          Healthcare  2024     244.384000
# 301                 Healthcare Plans          Healthcare  2023     195.187000
# 302                 Healthcare Plans          Healthcare  2022     180.031000
# 303  Insurance - Property & Casualty  Financial Services  2024      11.337000
# 304  Insurance - Property & Casualty  Financial Services  2023      10.013000
# 305  Insurance - Property & Casualty  Financial Services  2022       6.563000
# 312              Banks - Diversified  Financial Services  2024      81.089000
# 313              Banks - Diversified  Financial Services  2023      77.024000
# 314              Banks - Diversified  Financial Services  2022      74.480000
# 315                 Banks - Regional  Financial Services  2024       7.794000
# 316                 Banks - Regional  Financial Services  2023       8.224000
# 317                 Banks - Regional  Financial Services  2022       8.021000
#
#     revenue_currency  net_income_in_$B  gross_profit_in_$B  \
# 24               USD          5.443000                 NaN
# 25               USD          4.659000                 NaN
# 26               USD          4.418000                 NaN
# 54               USD          4.667000                 NaN
# 55               USD         -0.188000                 NaN
# 56               USD         -1.289000                 NaN
# 78               USD         10.129000                 NaN
# 79               USD          8.374000                 NaN
# 80               USD          7.514000                 NaN
# 81               USD         -1.404000                 NaN
# 82               USD          3.643000                 NaN
# 83               USD         10.227000                 NaN
# 90               USD          3.401000                 NaN
# 91               USD          2.556000                 NaN
# 92               USD          3.149000                 NaN
# 126              USD          4.312000                 NaN
# 127              USD          4.443000                 NaN
# 128              USD          1.476000                 NaN
# 138              USD          0.760200                 NaN
# 139              USD          0.642500                 NaN
# 140              USD          0.276600                 NaN
# 171              USD         27.132000                 NaN
# 172              USD         26.515000                 NaN
# 173              USD         27.528000                 NaN
# 192              USD          2.776508                 NaN
# 193              USD          1.390880                 NaN
# 194              USD          1.747631                 NaN
# 198              USD          4.530000                 NaN
# 199              USD          3.302000                 NaN
# 200              USD          2.556000                 NaN
# 204              USD          5.882000                 NaN
# 205              USD          4.289000                 NaN
# 206              USD          3.058000                 NaN
# 243              USD          4.750000                 NaN
# 244              USD          4.887000                 NaN
# 245              USD          7.360000                 NaN
# 282              USD          5.942000                 NaN
# 283              USD          5.067000                 NaN
# 284              USD          7.183000                 NaN
# 294              USD          9.272000                 NaN
# 295              USD          9.028000                 NaN
# 296              USD          5.246000                 NaN
# 300              USD          3.434000                 NaN
# 301              USD          5.164000                 NaN
# 302              USD          6.704000                 NaN
# 303              USD          2.292000                 NaN
# 304              USD          1.843000                 NaN
# 305              USD         -0.487000                 NaN
# 312              USD         12.682000                 NaN
# 313              USD          9.228000                 NaN
# 314              USD         14.845000                 NaN
# 315              USD          1.509000                 NaN
# 316              USD          1.608000                 NaN
# 317              USD          2.073000                 NaN
#
#      total_assets_in_$B  employees  market_cap_in_$B
# 24           117.566000      12694         58.344763
# 25           126.724000      12694         58.344763
# 26           131.738000      12694         58.344763
# 54           111.617000      55000         54.993560
# 55           103.362000      55000         54.993560
# 56            97.989000      55000         54.993560
# 78           271.461000      75100        257.462518
# 79           261.108000      75100        257.462518
# 80           228.354000      75100        257.462518
# 81           161.322000      22200         42.572427
# 82           539.306000      22200         42.572427
# 83           522.228000      22200         42.572427
# 90           181.403000      10000         44.171141
# 91           175.191000      10000         44.171141
# 92           158.852000      10000         44.171141
# 126           70.906000       7200         34.694558
# 127           58.906000       7200         34.694558
# 128           47.990000       7200         34.694558
# 138           35.020600      14200         11.165362
# 139           33.635200      14200         11.165362
# 140           33.117300      14200         11.165362
# 171         3261.519000     213000        401.338794
# 172         3180.151000     213000        401.338794
# 173         3051.375000     213000        401.338794
# 192           43.469875       4895        185.586500
# 193           40.287530       4895        185.586500
# 194           42.524227       4895        185.586500
# 198          416.064000      49200         79.967257
# 199          409.877000      49200         79.967257
# 200          405.783000      49200         79.967257
# 204           27.708000      24800        164.134683
# 205           24.342000      24800        164.134683
# 206           25.361000      24800        164.134683
# 243          490.144000      77000        145.215193
# 244          478.464000      77000        145.215193
# 245          455.249000      77000        145.215193
# 282          479.843000      32700        170.049749
# 283          493.178000      32700        170.049749
# 284          551.772000      32700        170.049749
# 294          246.548000      43000        117.595693
# 295          230.682000      43000        117.595693
# 296          199.017000      43000        117.595693
# 300          155.881000      71295         72.570077
# 301          152.761000      71295         72.570077
# 302          143.885000      71295         72.570077
# 303           36.501000       5624         25.469026
# 304           32.769000       5624         25.469026
# 305           29.732000       5624         25.469026
# 312         2352.945000     227000        195.917562
# 313         2411.834000     227000        195.917562
# 314         2416.676000     227000        195.917562
# 315          217.521000      17496         23.924773
# 316          221.964000      17496         23.924773
# 317          226.733000      17496         23.924773

# %%
# Fill gross_profit_in_$B with median *within each sector*
financial_dataset["gross_profit_in_$B"] = (
    financial_dataset
    .groupby("sector")["gross_profit_in_$B"]
    .transform(lambda s: s.fillna(s.median()))
)

# Fill employees with median *within each industry*
financial_dataset["employees"] = (
    financial_dataset
    .groupby("industry")["employees"]
    .transform(lambda s: s.fillna(s.median()))
    .round(0)
    .astype("Int64")
)

financial_dataset.isna().sum()
# Out:
# ticker                0
# company_name          0
# country               0
# industry              0
# sector                0
# year                  0
# revenue_in_$B         0
# revenue_currency      0
# net_income_in_$B      0
# gross_profit_in_$B    0
# total_assets_in_$B    0
# employees             0
# market_cap_in_$B      0
# dtype: int64

# %% [markdown]
# This way:
#
# * Missing gross profit for a tech company is filled using other tech companies.
#
# * Missing employees for a pharma firm is filled using other pharma companies.

# %% [markdown]
# ## Step 6 – Save the dataset to CSV and Excel
#
# Finally, the dataset is saved so that it can be used outside of this
# notebook (for example in Excel, Power BI, or another project).
#
# Two files are written into the current working directory:
#
# - `company_financials_long_format.csv`
# - `company_financials_long_format.xlsx`

# %%
csv_path = "company_financials_long_format.csv"
xlsx_path = "company_financials_long_format.xlsx"

#financial_dataset.to_csv(csv_path, index=False)
#financial_dataset.to_excel(xlsx_path, index=False)

print("Saved CSV to:", csv_path)
print("Saved Excel to:", xlsx_path)
# Out:
# Saved CSV to: company_financials_long_format.csv
# Saved Excel to: company_financials_long_format.xlsx

# %% [markdown]
# ## Recap
#
# In this notebook I have:
#
# 1. Loaded a list of S&P 500 companies using `requests` + BeautifulSoup.
# 2. Used `yfinance` to talk to Yahoo Finance.
# 3. Pulled metadata (company name, country, industry, sector, currency).
# 4. Pulled up to 3 years of annual financial statements for each company.
# 5. Combined everything into one tidy pandas DataFrame.
# 6. Saved the result as both CSV and Excel files.
